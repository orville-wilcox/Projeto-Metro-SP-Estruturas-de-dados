# %%
import networkx as nx 
import pandas as pd
from geopy.distance import distance

# %%
metro_df = pd.read_csv('metroetrem_sp_comlinks.csv') #carregando a base de dados fornecida em um dataframe
metro_df.head(10) #visualizando como está nosso dataframe
# Out:
#    num_lin nome_lin       long        lat             estacao_upp  \
# 0        4  AMARELA -46.723768 -23.586440       SAO PAULO MORUMBI
# 1        4  AMARELA -46.708157 -23.571857                 BUTANTA
# 2        4  AMARELA -46.701610 -23.567392               PINHEIROS
# 3        4  AMARELA -46.694102 -23.567269              FARIA LIMA
# 4        4  AMARELA -46.684259 -23.566228       FRADIQUE COUTINHO
# 5        4  AMARELA -46.671921 -23.560521            OSCAR FREIRE
# 6        4  AMARELA -46.662161 -23.555044                PAULISTA
# 7        4  AMARELA -46.652165 -23.548935  HIGIENOPOLIS MACKENZIE
# 8        4  AMARELA -46.642737 -23.544291               REPUBLICA
# 9        4  AMARELA -46.634499 -23.536259                     LUZ
#
#                      link
# 0                 BUTANTA
# 1               PINHEIROS
# 2              FARIA LIMA
# 3       FRADIQUE COUTINHO
# 4            OSCAR FREIRE
# 5                PAULISTA
# 6  HIGIENOPOLIS MACKENZIE
# 7               REPUBLICA
# 8                     LUZ
# 9                     LUZ

# %% [markdown]
# Vamos dividir nosso Dataframe em partes, fazendo um novo DF para cada uma das linhas de metrô. Para isso vamos visualizar quais são as linhas existentes em nosso DF

# %%
metro_df['nome_lin'].value_counts()
# Out:
# AZUL         23
# DIAMANTE     22
# RUBI         19
# ESMERALDA    18
# VERMELHA     18
# LILAS        17
# CORAL        16
# VERDE        14
# SAFIRA       13
# TURQUESA     13
# AMARELA      10
# PRATA        10
# JADE          3
# Name: nome_lin, dtype: int64

# %% [markdown]
# Podemos ver um total de 13 linhas distintas, algumas com menos, outras com mais estações, para cada uma delas criaremos um novo DF:

# %%
lista_dfs = [] #inicializando uma lista vazia, onde serão salvos os dataframes separadamente
linha_azul_df = metro_df.loc[metro_df['nome_lin'] == 'AZUL'].reset_index() #cria-se o novo DF usando o método loc 
#para determinar qual a linha desejada, e o método reset_index para que os indices mantenham uma ordem condizente
lista_dfs.append(linha_azul_df) #salvamos o novo DF em nossa lista e repetimos o processo para cada linha possível
linha_prata_df = metro_df.loc[metro_df['nome_lin'] == 'PRATA'].reset_index()
lista_dfs.append(linha_prata_df)
linha_amarela_df = metro_df.loc[metro_df['nome_lin'] == 'AMARELA'].reset_index()
lista_dfs.append(linha_amarela_df)
linha_lilas_df = metro_df.loc[metro_df['nome_lin'] == 'LILAS'].reset_index()
lista_dfs.append(linha_lilas_df)
linha_verde_df = metro_df.loc[metro_df['nome_lin'] == 'VERDE'].reset_index()
lista_dfs.append(linha_verde_df)
linha_coral_df = metro_df.loc[metro_df['nome_lin'] == 'CORAL'].reset_index()
lista_dfs.append(linha_coral_df)
linha_diamante_df = metro_df.loc[metro_df['nome_lin'] == 'DIAMANTE'].reset_index()
lista_dfs.append(linha_diamante_df)
linha_safira_df = metro_df.loc[metro_df['nome_lin'] == 'SAFIRA'].reset_index()
lista_dfs.append(linha_safira_df)
linha_vermelha_df = metro_df.loc[metro_df['nome_lin'] == 'VERMELHA'].reset_index()
lista_dfs.append(linha_vermelha_df)
linha_esmeralda_df = metro_df.loc[metro_df['nome_lin'] == 'ESMERALDA'].reset_index()
lista_dfs.append(linha_esmeralda_df)
linha_jade_df = metro_df.loc[metro_df['nome_lin'] == 'JADE'].reset_index()
lista_dfs.append(linha_jade_df)
linha_rubi_df = metro_df.loc[metro_df['nome_lin'] == 'RUBI'].reset_index()
lista_dfs.append(linha_rubi_df)
linha_turquesa_df = metro_df.loc[metro_df['nome_lin'] == 'TURQUESA'].reset_index()
lista_dfs.append(linha_turquesa_df)

# %% [markdown]
# Vamos visualizar como ficaram estes dataframes individuais, observando como exemplo a linha Jade:

# %%
linha_jade_df.head()
# Out:
#    index  num_lin nome_lin       long        lat          estacao_upp  \
# 0     89       13     JADE -46.520822 -23.497915   ENGENHEIRO GOULART
# 1     90       13     JADE -46.493596 -23.447484      GUARULHOS CECAP
# 2     91       13     JADE -46.493781 -23.433131  AEROPORTO GUARULHOS
#
#                   link
# 0      GUARULHOS CECAP
# 1  AEROPORTO GUARULHOS
# 2  AEROPORTO GUARULHOS

# %% [markdown]
# É de grande interesse saber a distância existente entre as duas estações que se ligam, e podemos notar que temos em cada linha as coordenadas de latitude e longitude da "estacao_upp". Podemos usar dessa informação para criar uma nova coluna em nosso DataFrame com a distancia percorrida entre as estações ligadas.
# Para isso definimos a função insere_distancias, que recebe como parametro um de nossos dataframes, e para cada par de linhas consecutivas passa as informações de coordenadas para o método geopy.distance.distance, que retorna a distância geodésica entre as coordenadas (em quilometros, neste projeto). Tais distâncias são salvas em uma lista que é retornada ao final da execução.
# OBS: Note que a última linha de cada DF mostra uma estação ligada a si propria, por isso ao final do loop da função adiciona-se o valor 0 na lista.

# %%
def insere_distancias(df):
    distancias=[]
    for i in range(df.shape[0]-1): #loop para percorrer o data frame
        #Pega as coordenadas de uma linha (estação 'atual') e da linha seguinte ('proxima' estação) e calcula a distancia entre elas
        distancia = distance((df['lat'][i], df['long'][i]), (df['lat'][i+1], df['long'][i+1])).km 
        distancias.append(round(distancia,3)) #A distancia é salva em uma lista, arredondada em 3 casas decimais
    distancias.append(0) #Ultima linha recebe 0 pois corresponderá a uma estação ligada a si mesma
    return distancias #retorna a lista com as distancias

# %%
grafo_metro = nx.Graph() #Vamos inicializar um grafo vazio
for df in lista_dfs: #percorrendo nossa lista de dataframes 
    df['distancias']=insere_distancias(df) #Criamos em cada um a coluna de distancias
    #Usadno o metodo from_pandas_edgelist criamos um grafo onde cada estacao é um nó ligado a uma outra estaçao e as distancias
    #entre elas são passadas como parametro para a aresta
    grafo_linha = nx.from_pandas_edgelist(df, 'estacao_upp', 'link',edge_attr='distancias') 
    #Usando o método Compose mesclamos o grafo com o que foi inicializado previamente, até que todas nossas linhas estejam
    #reunidas em um unico grafo
    grafo_metro = nx.compose(grafo_metro, grafo_linha)

# %% [markdown]
# Vejamos se conseguimos extrair agora diretamente do grafo a informação de distancia entre estações

# %%
nx.get_edge_attributes(grafo_metro, 'distancias')
# Out:
# {('JABAQUARA', 'CONCEICAO'): 1.21,
#  ('CONCEICAO', 'SAO JUDAS'): 1.09,
#  ('SAO JUDAS', 'SAUDE'): 0.807,
#  ('SAUDE', 'PRACA DA ARVORE'): 0.873,
#  ('PRACA DA ARVORE', 'SANTA CRUZ'): 1.295,
#  ('SANTA CRUZ', 'VILA MARIANA'): 1.091,
#  ('SANTA CRUZ', 'HOSPITAL SAO PAULO'): 0.88,
#  ('SANTA CRUZ', 'CHACARA KLABIN'): 0.828,
#  ('VILA MARIANA', 'ANA ROSA'): 0.974,
#  ('ANA ROSA', 'PARAISO'): 0.667,
#  ('ANA ROSA', 'CHACARA KLABIN'): 1.5,
#  ('PARAISO', 'VERGUEIRO'): 0.745,
#  ('PARAISO', 'BRIGADEIRO'): 0.996,
#  ('VERGUEIRO', 'SAO JOAQUIM'): 0.816,
#  ('SAO JOAQUIM', 'JAPAO LIBERDADE'): 0.797,
#  ('JAPAO LIBERDADE', 'SE'): 0.624,
#  ('SE', 'SAO BENTO'): 0.666,
#  ('SE', 'ANHANGABAU'): 0.655,
#  ('SE', 'PEDRO II'): 0.748,
#  ('SAO BENTO', 'LUZ'): 0.818,
#  ('LUZ', 'TIRADENTES'): 0.675,
#  ('LUZ', 'REPUBLICA'): 1.224,
#  ('LUZ', 'LUZ'): 0.0,
#  ('LUZ', 'BRAS'): 2.193,
#  ('LUZ', 'BARRA FUNDA'): 3.447,
#  ('TIRADENTES', 'ARMENIA'): 0.672,
#  ('ARMENIA', 'PORTUGUESA TIETE'): 1.107,
#  ('PORTUGUESA TIETE', 'CARANDIRU'): 0.744,
#  ('CARANDIRU', 'SANTANA'): 0.766,
#  ('SANTANA', 'JARDIM SAO PAULO AYRTON SENNA'): 1.373,
#  ('JARDIM SAO PAULO AYRTON SENNA', 'PARADA INGLESA'): 1.036,
#  ('PARADA INGLESA', 'TUCURUVI'): 0.952,
#  ('TUCURUVI', 'TUCURUVI'): 0.0,
#  ('VILA PRUDENTE', 'ORATORIO'): 2.201,
#  ('VILA PRUDENTE', 'TAMANDUATEI'): 1.258,
#  ('VILA PRUDENTE', 'VILA PRUDENTE'): 0.0,
#  ('ORATORIO', 'SAO LUCAS'): 1.905,
#  ('SAO LUCAS', 'CAMILO HADDAD'): 1.018,
#  ('CAMILO HADDAD', 'VILA TOLSTOI'): 1.217,
#  ('VILA TOLSTOI', 'VILA UNIAO'): 1.22,
#  ('VILA UNIAO', 'JARDIM PLANALTO'): 0.894,
#  ('JARDIM PLANALTO', 'SAPOPEMBA'): 1.147,
#  ('SAPOPEMBA', 'FAZENDA DA JUTA'): 1.4,
#  ('FAZENDA DA JUTA', 'SAO MATEUS'): 1.091,
#  ('SAO MATEUS', 'SAO MATEUS'): 0.0,
#  ('SAO PAULO MORUMBI', 'BUTANTA'): 2.269,
#  ('BUTANTA', 'PINHEIROS'): 0.831,
#  ('PINHEIROS', 'FARIA LIMA'): 0.767,
#  ('PINHEIROS', 'HEBRAICA REBOUCAS'): 0.904,
#  ('PINHEIROS', 'CIDADE UNIVERSITARIA'): 1.34,
#  ('FARIA LIMA', 'FRADIQUE COUTINHO'): 1.011,
#  ('FRADIQUE COUTINHO', 'OSCAR FREIRE'): 1.409,
#  ('OSCAR FREIRE', 'PAULISTA'): 1.167,
#  ('PAULISTA', 'HIGIENOPOLIS MACKENZIE'): 1.224,
#  ('HIGIENOPOLIS MACKENZIE', 'REPUBLICA'): 1.091,
#  ('REPUBLICA', 'SANTA CECILIA'): 0.692,
#  ('REPUBLICA', 'ANHANGABAU'): 0.621,
#  ('CAPAO REDONDO', 'CAMPO LIMPO'): 1.438,
#  ('CAMPO LIMPO', 'VILA DAS BELEZAS'): 1.669,
#  ('VILA DAS BELEZAS', 'GIOVANNI GRONCHI'): 1.249,
#  ('GIOVANNI GRONCHI', 'SANTO AMARO'): 1.876,
#  ('SANTO AMARO', 'LARGO TREZE'): 1.28,
#  ('SANTO AMARO', 'SOCORRO'): 1.07,
#  ('SANTO AMARO', 'GRANJA JULIETA'): 3.257,
#  ('LARGO TREZE', 'ADOLFO PINHEIRO'): 0.623,
#  ('ADOLFO PINHEIRO', 'ALTO DA BOA VISTA'): 1.087,
#  ('ALTO DA BOA VISTA', 'BORBA GATO'): 1.059,
#  ('BORBA GATO', 'BROOKLIN'): 0.913,
#  ('BROOKLIN', 'CAMPO BELO'): 1.077,
#  ('CAMPO BELO', 'EUCALIPTOS'): 1.707,
#  ('EUCALIPTOS', 'MOEMA'): 0.94,
#  ('MOEMA', 'AACD SERVIDOR'): 1.224,
#  ('AACD SERVIDOR', 'HOSPITAL SAO PAULO'): 0.709,
#  ('CHACARA KLABIN', 'CHACARA KLABIN'): 0.0,
#  ('CHACARA KLABIN', 'SANTOS IMIGRANTES'): 1.033,
#  ('VILA MADALENA', 'SANTUARIO NOSSA SENHORA DE FATIMA SUMARE'): 1.483,
#  ('SANTUARIO NOSSA SENHORA DE FATIMA SUMARE', 'CLINICAS'): 0.71,
#  ('CLINICAS', 'CONSOLACAO'): 1.093,
#  ('CONSOLACAO', 'TRIANON MASP'): 0.926,
#  ('TRIANON MASP', 'BRIGADEIRO'): 0.963,
#  ('SANTOS IMIGRANTES', 'ALTO DO IPIRANGA'): 1.113,
#  ('ALTO DO IPIRANGA', 'SACOMA'): 0.99,
#  ('SACOMA', 'TAMANDUATEI'): 1.64,
#  ('TAMANDUATEI', 'IPIRANGA'): 1.399,
#  ('TAMANDUATEI', 'SAO CAETANO DO SUL PREFEITO WALTER BRAIDO'): 2.733,
#  ('BRAS', 'TATUAPE'): 4.131,
#  ('BRAS', 'PEDRO II'): 1.035,
#  ('BRAS', 'BRESSER MOOCA'): 0.863,
#  ('BRAS', 'BRAS'): 0.0,
#  ('BRAS', 'JUVENTUS MOOCA'): 1.701,
#  ('TATUAPE', 'CORINTHIANS ITAQUERA'): 10.753,
#  ('TATUAPE', 'ENGENHEIRO GOULART'): 7.343,
#  ('TATUAPE', 'BELEM'): 1.381,
#  ('TATUAPE', 'CARRAO'): 1.285,
#  ('CORINTHIANS ITAQUERA', 'DOM BOSCO'): 2.349,
#  ('CORINTHIANS ITAQUERA', 'ARTUR ALVIM'): 1.393,
#  ('CORINTHIANS ITAQUERA', 'CORINTHIANS ITAQUERA'): 0.0,
#  ('DOM BOSCO', 'JOSE BONIFACIO'): 1.729,
#  ('JOSE BONIFACIO', 'GUAIANASES'): 1.676,
#  ('GUAIANASES', 'ANTONIO GIANETTI NETO'): 3.494,
#  ('ANTONIO GIANETTI NETO', 'FERRAZ DE VASCONCELOS'): 2.142,
#  ('FERRAZ DE VASCONCELOS', 'POA'): 3.098,
#  ('POA', 'CALMON VIANA'): 3.771,
#  ('CALMON VIANA', 'SUZANO'): 2.733,
#  ('CALMON VIANA', 'ARACARE'): 2.807,
#  ('CALMON VIANA', 'CALMON VIANA'): 0.0,
#  ('SUZANO', 'JUNDIAPEBA'): 7.889,
#  ('JUNDIAPEBA', 'BRAS CUBAS'): 2.806,
#  ('BRAS CUBAS', 'MOGI DAS CRUZES'): 3.809,
#  ('MOGI DAS CRUZES', 'ESTUDANTES'): 1.502,
#  ('ESTUDANTES', 'ESTUDANTES'): 0.0,
#  ('AMADOR BUENO', 'SANTA RITA'): 4.026,
#  ('SANTA RITA', 'ITAPEVI'): 1.273,
#  ('ITAPEVI', 'ENGENHEIRO CARDOSO'): 1.316,
#  ('ENGENHEIRO CARDOSO', 'SAGRADO CORACAO'): 1.39,
#  ('SAGRADO CORACAO', 'JANDIRA'): 1.468,
#  ('JANDIRA', 'JARDIM SILVEIRA'): 1.004,
#  ('JARDIM SILVEIRA', 'JARDIM BELVAL'): 1.171,
#  ('JARDIM BELVAL', 'BARUERI'): 1.426,
#  ('BARUERI', 'ANTONIO JOAO'): 1.768,
#  ('ANTONIO JOAO', 'SANTA TERESINHA'): 1.106,
#  ('SANTA TERESINHA', 'CARAPICUIBA'): 1.275,
#  ('CARAPICUIBA', 'GENERAL MIGUEL COSTA'): 2.061,
#  ('GENERAL MIGUEL COSTA', 'QUITAUNA'): 0.936,
#  ('QUITAUNA', 'COMANDANTE SAMPAIO'): 1.162,
#  ('COMANDANTE SAMPAIO', 'OSASCO'): 2.073,
#  ('OSASCO', 'PRESIDENTE ALTINO'): 1.486,
#  ('OSASCO', 'OSASCO'): 0.0,
#  ('PRESIDENTE ALTINO', 'IMPERATRIZ LEOPOLDINA'): 2.659,
#  ('PRESIDENTE ALTINO', 'CEASA'): 2.108,
#  ('IMPERATRIZ LEOPOLDINA', 'DOMINGOS DE MORAIS'): 1.589,
#  ('DOMINGOS DE MORAIS', 'LAPA DIAMANTE'): 2.404,
#  ('LAPA DIAMANTE', 'BARRA FUNDA'): 3.286,
#  ('BARRA FUNDA', 'JULIO PRESTES'): 2.853,
#  ('BARRA FUNDA', 'AGUA BRANCA'): 2.21,
#  ('JULIO PRESTES', 'JULIO PRESTES'): 0.0,
#  ('ENGENHEIRO GOULART', 'USP LESTE'): 2.401,
#  ('ENGENHEIRO GOULART', 'GUARULHOS CECAP'): 6.24,
#  ('USP LESTE', 'COMENDADOR ERMELINO'): 1.979,
#  ('COMENDADOR ERMELINO', 'SAO MIGUEL PAULISTA'): 3.976,
#  ('SAO MIGUEL PAULISTA', 'JARDIM HELENA VILA MARA'): 2.287,
#  ('JARDIM HELENA VILA MARA', 'ITAIM PAULISTA'): 2.014,
#  ('ITAIM PAULISTA', 'JARDIM ROMANO'): 1.945,
#  ('JARDIM ROMANO', 'ENGENHEIRO MANUEL FEIO'): 1.929,
#  ('ENGENHEIRO MANUEL FEIO', 'ITAQUACETUBA'): 2.138,
#  ('ITAQUACETUBA', 'ARACARE'): 1.884,
#  ('PALMEIRAS BARRA FUNDA', 'MARECHAL DEODORO'): 1.49,
#  ('MARECHAL DEODORO', 'SANTA CECILIA'): 1.003,
#  ('BRESSER MOOCA', 'BELEM'): 1.85,
#  ('CARRAO', 'PENHA'): 2.28,
#  ('PENHA', 'VILA MATILDE'): 1.175,
#  ('VILA MATILDE', 'GUILHERMINA ESPERANCA'): 1.476,
#  ('GUILHERMINA ESPERANCA', 'PATRIARCA VILA RE'): 1.583,
#  ('PATRIARCA VILA RE', 'ARTUR ALVIM'): 1.992,
#  ('GRAJAU', 'PRIMAVERA INTERLAGOS'): 1.562,
#  ('PRIMAVERA INTERLAGOS', 'AUTODROMO'): 1.896,
#  ('AUTODROMO', 'JURUBATUBA'): 3.487,
#  ('JURUBATUBA', 'SOCORRO'): 1.858,
#  ('GRANJA JULIETA', 'MORUMBI'): 1.28,
#  ('MORUMBI', 'BERRINI'): 1.913,
#  ('BERRINI', 'VILA OLIMPIA'): 1.296,
#  ('VILA OLIMPIA', 'CIDADE JARDIM'): 0.91,
#  ('CIDADE JARDIM', 'HEBRAICA REBOUCAS'): 1.525,
#  ('CIDADE UNIVERSITARIA', 'VILLA LOBOS JAGUARE'): 2.528,
#  ('VILLA LOBOS JAGUARE', 'CEASA'): 1.318,
#  ('GUARULHOS CECAP', 'AEROPORTO GUARULHOS'): 1.59,
#  ('AEROPORTO GUARULHOS', 'AEROPORTO GUARULHOS'): 0.0,
#  ('JUNDIAI', 'VARZEA PAULISTA'): 4.657,
#  ('VARZEA PAULISTA', 'CAMPO LIMPO PAULISTA'): 4.455,
#  ('CAMPO LIMPO PAULISTA', 'BOTUJURU'): 3.789,
#  ('BOTUJURU', 'FRANCISCO MORATO'): 5.692,
#  ('FRANCISCO MORATO', 'BALTAZAR FIDELIS'): 3.638,
#  ('BALTAZAR FIDELIS', 'FRANCO DA ROCHA'): 2.178,
#  ('FRANCO DA ROCHA', 'CAIEIRAS'): 4.799,
#  ('CAIEIRAS', 'PERUS'): 4.304,
#  ('PERUS', 'VILA AURORA'): 3.69,
#  ('VILA AURORA', 'JARAGUA'): 2.148,
#  ('JARAGUA', 'VILA CLARICE'): 1.714,
#  ('VILA CLARICE', 'PIRITUBA'): 2.779,
#  ('PIRITUBA', 'PIQUERI'): 2.022,
#  ('PIQUERI', 'LAPA RUBI'): 1.93,
#  ('LAPA RUBI', 'AGUA BRANCA'): 1.622,
#  ('JUVENTUS MOOCA', 'IPIRANGA'): 2.849,
#  ('SAO CAETANO DO SUL PREFEITO WALTER BRAIDO', 'UTINGA'): 3.191,
#  ('UTINGA', 'PREFEITO SALADINO'): 1.546,
#  ('PREFEITO SALADINO', 'PREFEITO CELSO DANIEL SANTO ANDRE'): 1.778,
#  ('PREFEITO CELSO DANIEL SANTO ANDRE', 'CAPUAVA'): 3.944,
#  ('CAPUAVA', 'MAUA'): 3.105,
#  ('MAUA', 'GUAPITUBA'): 2.968,
#  ('GUAPITUBA', 'ANTONIO BESPALEC RIBEIRAO PIRES'): 4.196,
#  ('ANTONIO BESPALEC RIBEIRAO PIRES', 'RIO GRANDE DA SERRA'): 4.032,
#  ('RIO GRANDE DA SERRA', 'RIO GRANDE DA SERRA'): 0.0}

# %%
def melhor_caminho(origem, destino):
    trilha = nx.shortest_path(grafo_metro, source=origem, target=destino, weight='distancias', method='dijkstra')
    distancia_total = 0
    prev = trilha[0]
    
    for item in trilha[1:]:
        dist_percurso = grafo_metro[prev][item]['distancias']
        print(f'{prev} -> {item}     Distancia: {dist_percurso} Km')
        distancia_total += dist_percurso
        prev = item
    print(f'Distancia total do percurso: {round(distancia_total,3)} Km')

# %%
while True:
    ans = input('Informe uma estação de origem(não use acentos ou ç). Para sair digite sair\n').upper()
    if ans=='SAIR':
        break
    else:
        destino = input('Informe uma estação de destino(não use acentos ou ç).\n').upper()
    try:
        melhor_caminho(ans,destino)
    except:
        print('Dados inválidos. Tente Novamente.\n')
# Out:
# Informe uma estação de origem(não use acentos ou ç). Para sair digite sair
# se
# Informe uma estação de destino(não use acentos ou ç).
# luz
# SE -> SAO BENTO     Distancia: 0.666 Km
# SAO BENTO -> LUZ     Distancia: 0.818 Km
# Distancia total do percurso: 1.484 Km
# Informe uma estação de origem(não use acentos ou ç). Para sair digite sair
# anhangabau
# Informe uma estação de destino(não use acentos ou ç).
# vila matilde
# ANHANGABAU -> SE     Distancia: 0.655 Km
# SE -> PEDRO II     Distancia: 0.748 Km
# PEDRO II -> BRAS     Distancia: 1.035 Km
# BRAS -> BRESSER MOOCA     Distancia: 0.863 Km
# BRESSER MOOCA -> BELEM     Distancia: 1.85 Km
# BELEM -> TATUAPE     Distancia: 1.381 Km
# TATUAPE -> CARRAO     Distancia: 1.285 Km
# CARRAO -> PENHA     Distancia: 2.28 Km
# PENHA -> VILA MATILDE     Distancia: 1.175 Km
# Distancia total do percurso: 11.272 Km
# Informe uma estação de origem(não use acentos ou ç). Para sair digite sair
# sair
